# %% [markdown]
# # 01. Железо, операционная система и данные
#
# ## Для кого этот урок
# Этот материал для ученика 7 класса, который начинает программирование с нуля.
#
# ## Цель урока
# Понять, как компьютер выполняет программы и где хранятся данные.
#
# ## Что ученик должен уметь после урока
# 1. Объяснить роль процессора, оперативной памяти и диска.
# 2. Понимать, зачем нужна операционная система.
# 3. Отличать временное хранение данных от постоянного.
# 4. Связать переменную в Python с хранением данных в памяти.

# %% [markdown]
# ## 1) Что такое "железо"
#
# **Железо** - это физические части компьютера.
#
# - **CPU (процессор)** - "мозг", выполняет команды.
# - **RAM (оперативная память)** - хранит данные, пока программа запущена.
# - **SSD/HDD (диск)** - хранит файлы долго, даже когда компьютер выключен.
# - **Устройства ввода** - клавиатура, мышь, микрофон.
# - **Устройства вывода** - монитор, колонки, принтер.
#
# Аналогия с кухней:
# - CPU = повар,
# - RAM = стол, где готовят сейчас,
# - SSD = шкаф/холодильник, где хранятся продукты.

# %% [markdown]
# ## 2) Что такое операционная система (ОС)
#
# **Операционная система** - это главная программа, которая управляет всем компьютером.
#
# Примеры ОС:
# - Windows
# - macOS
# - Linux
# - Android (на телефонах)
#
# Что делает ОС:
# 1. Запускает программы.
# 2. Управляет файлами и папками.
# 3. Распределяет память и время процессора.
# 4. Позволяет программам "общаться" с устройствами (экран, клавиатура, сеть).

# %% [markdown]
# ## 3) Где хранятся данные
#
# - Пока программа работает: данные обычно в **RAM**.
# - Когда нужно сохранить надолго: записываем на **диск** в файл.
#
# Пример:
# - Ты ввел имя в программе -> оно в RAM.
# - Сохранил текстовый файл с результатом -> он на диске.

# %%
# Демонстрация: данные в переменной во время работы программы
player_name = "Вован"
score = 10
print("Игрок:", player_name)
print("Очки:", score)

# %% [markdown]
# ## 4) Мини-практика
#
# Ответь устно или в тетради:
# 1. Где лежит файл этого урока - в RAM или на диске?
# 2. Где хранится значение переменной `score` во время выполнения кода?
# 3. Почему без ОС сложно работать с программами?

# %% [markdown]
# ## Домашнее задание
# 1. Нарисуй схему: "Пользователь -> ОС -> Программа -> Железо".
# 2. Подпиши на схеме, где RAM, CPU и диск.
# 3. Придумай 2 примера данных, которые стоит хранить только временно, и 2 примера, которые надо сохранять в файл.
