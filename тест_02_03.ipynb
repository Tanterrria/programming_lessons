# %% [markdown]
# # Тестовое задание 02_03

# %% [markdown]
# Итак, это тестовое задание по темам ["Переменные и правила имен"]("url") и ["Типы данных"]("url"). Ты можешь работать с открытыми примерами, но лучше повторить, что мы уже делали, а только затем приступать к заданиям.

# %% [markdown]
# Подсказки, как выполнять задания:
# 1) В тестовом задании с выбором вариантов ответа первый вопрос решен в качестве примера, ответ введен в соответствующую переменную answer_1. Далее надо так же в соответствующие вопросы вводить правильные ответы. После ввода ответа не забудь нажать CTRL + ENTER в ячейке, чтобы компьютер запомнил твой ответ.
# 1) Ввод переменной - это присваивание ему какого-то значения. Пока в переменной есть какое-либо значение (даже None, которым обозначают пустоту), существует переменная. Пока мы ее не введем, то есть не присвоим ей значение, она не существует в выполняемом коде.
# 1) Для вывода значения, содержимого в переменной, используется функция print().

# %% [markdown]
# ## 1. Тестовые вопросы с выбором ответа
#
# 1) Где функция вывода написана верно? (вопрос для примера)
#
# 1. printf()
# 2. cout()
# 3. print()
# 4. write()

# %%
answer_1 = 3

# %% [markdown]
# 2) Что такое переменная в Python?
#
# 1. Тип данных
# 1. Операционная система
# 1. Ссылка на объект в памяти
# 1. Язык программирования

# %%
answer_2 =

# %% [markdown]
# 3) Что покажет приведённый ниже код?
# ```python
# num1 = 6
# num2 = 7
# num3 = num1 * num2
# print(num3)
# ```

# %%
answer_3 =

# %% [markdown]
# 4) Какое имя переменной введено неверно?
# 1. `my_city = "Dmitrov"`
# 1. `else = 7`
# 1. `_game_name = "Minecraft"`
# 1. `a, b = 8, 10`

# %%
answer_4 =

# %% [markdown]
# 5) Как называется целочисленный тип данных?
# 1. str
# 2. int
# 3. bool
# 4. float

# %%
answer_5 =

# %% [markdown]
# 5) Как вывести тип данных в переменной `name`?
# ```python
# 1. print(type(name))
# 2. print(name)
# 3. name
# 4. print(type('name'))
# ```

# %%
answer_6 =

# %% [markdown]
# Следующим этапом проверим правильность овтетов! Но ответы зашифрованы.
# Тебе надо только запустить ячейку ниже и проверить свои ответы на верность.
# Если хоть один из ответов не совпадет, он выдаст 'Вы ответили неправильно!'. Твоя задача - добиться совпадения ответов. Если не получается, пиши мне.

# %%
import math
answers = ''.join(str(x) for x in [
    answer_1,
    answer_2,
    answer_3,
    answer_4,
    answer_5,
    answer_6
])

i = 200
t = 110
if answers == str(math.comb(i,t))[:7]:
    print('Вы ответили правильно!')
else:
    print('Вы ответили неправильно!')

# %% [markdown]
# ## 2. Письменная часть
#
# В ячейке ниже:
# 1) исправь неправильные имена переменных:

# %%
1lesson = 'Maths'
my age = 20
# !name! = 'Dmitry'
True = 'yes'

# %% [markdown]
# 2) Введи переменную **nickname**. Придумай и присвой переменной любое строковое значение.
# 3) Введи переменную **age**. Придумай и присвой переменной любое целочисленное значение.
# 4) Введи переменную **height**. Придумай и присвой переменной любое число с плавающей точкой.
# 5) Введи переменную **is_student**. Присвой переменной любое булево значение.

# %% [markdown]
# 6. Выведи типы данных в переменных **nickname**, **age**, **height**, **is_student**

# %% [markdown]
# 7. Задачка со звездочкой!
# Что выведет код ниже?
# ```python
# s = 13
# k = -5
# d = s + 2
# s = d
# k = 2 * s
# print(s + k + d)
# ```

# %%
answer =
